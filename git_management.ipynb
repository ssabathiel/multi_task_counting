# %%
# Taken from: https://towardsdatascience.com/colaboratory-drive-github-the-workflow-made-simpler-bde89fba8a39

# %%
from google.colab import drive
from os.path import join

ROOT = '/content/drive'     # default for the drive
PROJ = 'MyDrive/embodied_counting'       # path to your project on Drive

GIT_USERNAME = "ssabathiel" 
GIT_TOKEN = "4zLSuExSEtg3uk4kkL2y"           
GIT_REPOSITORY = "embodied_counting"     


drive.mount(ROOT)           # we mount the drive at /content/drive

PROJECT_PATH = join(ROOT, PROJ)
#!mkdir "{PROJECT_PATH}"I    # in case we haven't created it already   

GIT_PATH = "https://{GIT_TOKEN}@gitlab.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git"
#!mkdir ./temp
#!git clone "{GIT_PATH}"
#!mv ./temp/* "{PROJECT_PATH}"
#!rm -rf ./temp
#!rsync -aP --exclude=data/ "{PROJECT_PATH}"/*  ./
# Out:
# Mounted at /content/drive

# %%
GIT_COMMIT_MESSAGE = 'updated all to minimal set of files'
GIT_EMAIL = 'ssabathiel@gmail.com'
GIT_NAME = 'ssabathiel'
GIT_BRANCH_NAME = 'master'

# %%
# !mkdir ./temp
# !git clone "https://ssabathiel:4zLSuExSEtg3uk4kkL2y@gitlab.com/ssabathiel/embodied_counting.git" ./temp#"https://{GIT_TOKEN}@gitlab.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" ./temp
# !rsync -aP --exclude=data/ "{PROJECT_PATH}"/* ./temp

# %cd ./temp
# !git add .
# !git commit -m '"{GIT_COMMIT_MESSAGE}"'
# !git config --global user.email "{GIT_EMAIL}"
# !git config --global user.name "{GIT_NAME}"
# !git push origin "{GIT_BRANCH_NAME}"
# %cd /content
# !rm -rf ./temp
# Out:
# mkdir: cannot create directory ‘./temp’: File exists
# fatal: Too many arguments.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --progress            force progress reporting
#     -n, --no-checkout     don't create a checkout
#     --bare                create a bare repository
#     --mirror              create a mirror repository (implies bare)
#     -l, --local           to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     -s, --shared          setup as shared repository
#     --recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
#     -j, --jobs <n>        number of submodules cloned in parallel
#     --template <template-directory>
#                           directory from which templates will be used
#     --reference <repo>    reference repository
#     --reference-if-able <repo>
#                           reference repository
#     --dissociate          use --reference only while cloning
#     -o, --origin <name>   use <name> instead of 'origin' to track upstream
#     -b, --branch <branch>
#                           checkout <branch> instead of the remote's HEAD
#     -u, --upload-pack <path>
#                           path to git-upload-pack on the remote
#     --depth <depth>       create a shallow clone of that depth
#     --shallow-since <time>
#                           create a shallow clone since a specific time
#     --shallow-exclude <revision>
#                           deepen history of shallow clone, excluding rev
#     --single-branch       clone only one branch, HEAD or --branch
#     --no-tags             don't clone any tags, and make later fetches not to follow them
#     --shallow-submodules  any cloned submodules will be shallow
#     --separate-git-dir <gitdir>
#                           separate git dir from working tree
#     -c, --config <key=value>
#                           set config inside the new repository
#     -4, --ipv4            use IPv4 addresses only
#     -6, --ipv6            use IPv6 addresses only
#     --filter <args>       object filtering
#
# sending incremental file list
# git_management.ipynb
#           3,651 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=39/40)
# Results/
# src/
# src/Arial.ttf
#         773,236 100%  122.90MB/s    0:00:00 (xfr#2, to-chk=36/40)
# src/imports.py
#             916 100%  149.09kB/s    0:00:00 (xfr#3, to-chk=35/40)
# src/internal_imports.py
#           1,388 100%  193.64kB/s    0:00:00 (xfr#4, to-chk=34/40)
# src/internal_imports_2.py
#           1,494 100%  182.37kB/s    0:00:00 (xfr#5, to-chk=33/40)
# src/environment/
# src/environment/counting_tasks.py
#          25,930 100%    2.75MB/s    0:00:00 (xfr#6, to-chk=26/40)
# src/environment/minimal_count_environment.py
#          38,013 100%    3.63MB/s    0:00:00 (xfr#7, to-chk=25/40)
# src/environment/solving_algorithms.py
#           8,222 100%  802.93kB/s    0:00:00 (xfr#8, to-chk=24/40)
# src/environment/task_utils.py
#           2,796 100%  248.22kB/s    0:00:00 (xfr#9, to-chk=23/40)
# src/environment/__pycache__/
# src/environment/__pycache__/counting_tasks.cpython-36.pyc
#          25,777 100%    2.05MB/s    0:00:00 (xfr#10, to-chk=21/40)
# src/environment/__pycache__/counting_tasks.cpython-37.pyc
#          26,016 100%    2.07MB/s    0:00:00 (xfr#11, to-chk=20/40)
# src/environment/__pycache__/minimal_count_environment.cpython-36.pyc
#          24,733 100%    1.81MB/s    0:00:00 (xfr#12, to-chk=19/40)
# src/environment/__pycache__/minimal_count_environment.cpython-37.pyc
#          24,412 100%    1.66MB/s    0:00:00 (xfr#13, to-chk=18/40)
# src/environment/__pycache__/task_utils.cpython-36.pyc
#           2,127 100%  138.48kB/s    0:00:00 (xfr#14, to-chk=17/40)
# src/environment/__pycache__/task_utils.cpython-37.pyc
#           2,120 100%  129.39kB/s    0:00:00 (xfr#15, to-chk=16/40)
# src/environment/__pycache__/test_class.cpython-36.pyc
#           4,479 100%  257.30kB/s    0:00:00 (xfr#16, to-chk=15/40)
# src/manage_results/
# src/manage_results/plot_hinton_diagrams.py
#          32,474 100%    1.72MB/s    0:00:00 (xfr#17, to-chk=14/40)
# src/manage_results/run_schedules.py
#           4,613 100%  237.10kB/s    0:00:00 (xfr#18, to-chk=13/40)
# src/manage_results/save_and_plot.py
#          19,111 100%  933.15kB/s    0:00:00 (xfr#19, to-chk=12/40)
# src/models/
# src/models/experimental_simplest_LangConvLSTM_with_graph.py
#          12,325 100%  601.81kB/s    0:00:00 (xfr#20, to-chk=11/40)
# src/notebooks/
# src/notebooks/demonstrate_solving_algorithms.ipynb
#          20,342 100%  945.96kB/s    0:00:00 (xfr#21, to-chk=10/40)
# src/notebooks/train_model.ipynb
#          42,324 100%    1.83MB/s    0:00:00 (xfr#22, to-chk=9/40)
# src/pics/
# src/pics/pointing.png
#          37,636 100%    1.56MB/s    0:00:00 (xfr#23, to-chk=8/40)
# src/pics/pointing_down.png
#          35,145 100%    1.40MB/s    0:00:00 (xfr#24, to-chk=7/40)
# src/pics/sound_off.png
#          44,599 100%    1.70MB/s    0:00:00 (xfr#25, to-chk=6/40)
# src/pics/sound_on.png
#          44,599 100%    1.64MB/s    0:00:00 (xfr#26, to-chk=5/40)
# src/pics/sound_on2.png
#           3,066 100%  115.16kB/s    0:00:00 (xfr#27, to-chk=4/40)
# src/train_and_test/
# src/train_and_test/demonstrate_model.py
#          24,622 100%  890.55kB/s    0:00:00 (xfr#28, to-chk=3/40)
# src/train_and_test/env_to_pytorch_interface.py
#          14,563 100%  507.92kB/s    0:00:00 (xfr#29, to-chk=2/40)
# src/train_and_test/test_model.py
#           9,692 100%  338.03kB/s    0:00:00 (xfr#30, to-chk=1/40)
# src/train_and_test/train_model_original.py
#           7,263 100%  244.58kB/s    0:00:00 (xfr#31, to-chk=0/40)
# /content/temp
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# /content
