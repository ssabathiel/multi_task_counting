# %%
# Taken from: https://towardsdatascience.com/colaboratory-drive-github-the-workflow-made-simpler-bde89fba8a39

# %%
from google.colab import drive
from os.path import join

ROOT = '/content/drive'     # default for the drive
PROJ = 'MyDrive/embodied_counting'       # path to your project on Drive

GIT_USERNAME = "USERNAME" 
GIT_TOKEN = "xxxxxxxxxxxxxxx"           
GIT_REPOSITORY = "embodied_counting"     


drive.mount(ROOT)           # we mount the drive at /content/drive

PROJECT_PATH = join(ROOT, PROJ)
#!mkdir "{PROJECT_PATH}"I    # in case we haven't created it already   

GIT_PATH = "https://{GIT_TOKEN}@gitlab.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git"
#!mkdir ./temp
#!git clone "{GIT_PATH}"
#!mv ./temp/* "{PROJECT_PATH}"
#!rm -rf ./temp
#!rsync -aP --exclude=data/ "{PROJECT_PATH}"/*  ./
# Out:
# Mounted at /content/drive

# %%
GIT_COMMIT_MESSAGE = 'updated all to minimal set of files'
GIT_EMAIL = 'ssabathiel@gmail.com'
GIT_NAME = 'ssabathiel'
GIT_BRANCH_NAME = 'master'

# %%
# !rm -rf ./temp
# !mkdir ./temp
# !git clone "https://ssabathiel:xxxxxxxxxxxx@gitlab.com/ssabathiel/embodied_counting.git" ./temp #"https://{GIT_TOKEN}@gitlab.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" ./temp
# !rsync -aP --exclude=data/ "{PROJECT_PATH}"/* ./temp

# %cd ./temp
# !git add .
# !git commit -m '"{GIT_COMMIT_MESSAGE}"'
# !git config --global user.email "{GIT_EMAIL}"
# !git config --global user.name "{GIT_NAME}"
# !git push origin "{GIT_BRANCH_NAME}"
# %cd /content
# !rm -rf ./temp
# Out:
# Cloning into './temp'...
# remote: Enumerating objects: 192, done.
# remote: Counting objects: 100% (192/192), done.
# remote: Compressing objects: 100% (164/164), done.
# remote: Total 192 (delta 52), reused 127 (delta 24), pack-reused 0
# Receiving objects: 100% (192/192), 41.27 MiB | 8.65 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# sending incremental file list
# git_management.ipynb
#           9,463 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=39/40)
# Results/
# src/
# src/Arial.ttf
#         773,236 100%  147.48MB/s    0:00:00 (xfr#2, to-chk=36/40)
# src/imports.py
#             916 100%  149.09kB/s    0:00:00 (xfr#3, to-chk=35/40)
# src/internal_imports.py
#           1,388 100%  225.91kB/s    0:00:00 (xfr#4, to-chk=34/40)
# src/internal_imports_2.py
#           1,494 100%  208.43kB/s    0:00:00 (xfr#5, to-chk=33/40)
# src/environment/
# src/environment/counting_tasks.py
#          25,930 100%    3.53MB/s    0:00:00 (xfr#6, to-chk=26/40)
# ...
